# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output.csv')

# %%
df
# Out:
#          algorithm  string_length  pattern_length  avg_time_ns
# 0       bruteforce            100               2         5900
# 1              kmp            100               2         5700
# 2      boyer_moore            100               2         6600
# 3       bruteforce            100               2         4100
# 4              kmp            100               2         4800
# ...            ...            ...             ...          ...
# 73495          kmp          10000              50       285000
# 73496  boyer_moore          10000              50        38700
# 73497   bruteforce          10000              50       339100
# 73498          kmp          10000              50       275500
# 73499  boyer_moore          10000              50        41700
#
# [73500 rows x 4 columns]

# %%
import os
if not os.path.isdir('images/'):
    os.makedirs('images/')

# %%
import seaborn as sns

for alg in df['algorithm'].unique():
    sns.lineplot(data=df[df.algorithm == alg], x='string_length', y='avg_time_ns', label=alg)
plt.legend()
plt.savefig('images/fig1.png')
plt.show()
# Out:
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
for alg in df['algorithm'].unique():
    sns.lineplot(data=df[(df.algorithm == alg) & (df.pattern_length < 10)], x='string_length', y='avg_time_ns',
                 label=alg)
plt.legend()
plt.savefig('images/fig2.png')
plt.show()
# Out:
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
for alg in df['algorithm'].unique():
    sns.lineplot(data=df[(df.algorithm == alg) & (df.pattern_length == 50)], x='string_length', y='avg_time_ns',
                 label=alg)
plt.legend()
plt.savefig('images/fig3.png')
plt.show()
# Out:
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
