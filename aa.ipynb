# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output.csv')

# %%
df
# Out:
#          algorithm  string_length  pattern_length  avg_time_ns
# 0       bruteforce            100               2       4100.0
# 1       bruteforce            100               3       3640.0
# 2       bruteforce            100               4       4280.0
# 3       bruteforce            100               5       3380.0
# 4       bruteforce            100               6       3340.0
# ...            ...            ...             ...          ...
# 14695  boyer_moore          10000              46      55280.0
# 14696  boyer_moore          10000              47      46420.0
# 14697  boyer_moore          10000              48      39740.0
# 14698  boyer_moore          10000              49      37220.0
# 14699  boyer_moore          10000              50      37600.0
#
# [14700 rows x 4 columns]

# %%
import seaborn as sns
for alg in df['algorithm'].unique():
    sns.lineplot(data=df[df.algorithm == alg], x='string_length', y='avg_time_ns', label=alg)
plt.legend()
plt.savefig('fig.png')
plt.show()
# Out:
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mo\.conda\envs\ml\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
